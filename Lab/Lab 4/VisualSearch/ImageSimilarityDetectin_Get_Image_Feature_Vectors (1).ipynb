# %%
#################################################
# Imports and function definitions
#################################################
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# %%
################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor

def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

# %%
#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)
    
get_image_feature_vectors()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Fri Apr  2 14:03:58 2021
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Fri Apr  2 14:04:11 2021
# --- 0.22 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Fri Apr  2 14:04:11 2021
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\0536ef5660e47128e9fde8a25f547db0785b2851.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/0536ef5660e47128e9fde8a25f547db0785b2851.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\0b96264a36e951c2cb4fba7c3cd913fc0274cba4.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/0b96264a36e951c2cb4fba7c3cd913fc0274cba4.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\114b8d92dfe9d1c38719135bc885a2220636eca3.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/114b8d92dfe9d1c38719135bc885a2220636eca3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\14f54167bfbf4393f0990334efb292242576bb51.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/14f54167bfbf4393f0990334efb292242576bb51.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\158c42c84260dafc49793ce3a2e7fac1b73fba5e.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/158c42c84260dafc49793ce3a2e7fac1b73fba5e.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\22abf56814e371a73528d22848889f84168dc29a.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/22abf56814e371a73528d22848889f84168dc29a.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\2ed31f58c2be08027b4d060dca7b80d905e9213b.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/2ed31f58c2be08027b4d060dca7b80d905e9213b.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\3093418aba5897313303ae15e43275671fabe473.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/3093418aba5897313303ae15e43275671fabe473.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\46921cd403370e7ab8a098843adaf29cb230537d.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/46921cd403370e7ab8a098843adaf29cb230537d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.npz
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\4dad9e43db72c2609856b02abced3755ef566383.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/4dad9e43db72c2609856b02abced3755ef566383.npz
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\535d914ddb7bedac122a9c158012a52defbdb28e.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/535d914ddb7bedac122a9c158012a52defbdb28e.npz
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.npz
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\623b50a4f2965c9fe8c453487dd288f998b51297.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/623b50a4f2965c9fe8c453487dd288f998b51297.npz
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\6e98e17cfef862fa83abdf351a23310d608b2b20.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/6e98e17cfef862fa83abdf351a23310d608b2b20.npz
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\73359c7cf3b04499250039ccb456eb168afa8704.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/73359c7cf3b04499250039ccb456eb168afa8704.npz
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\76e7932694833640c2af61030e40fd72997e7e24.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/76e7932694833640c2af61030e40fd72997e7e24.npz
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\77e23064334f0ab47f9bd17e232bdd941b2e6c1d.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test/77e23064334f0ab47f9bd17e232bdd941b2e6c1d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :21
# Image in process is             :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test\8893ea64a332765217b26680f925342a1bb4d301.jpg
# Image feature vector saved to   :C:/Users/aishwarya/Desktop/ADM/lab4/ImageSimilarityDetection-master/test